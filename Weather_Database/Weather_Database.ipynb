# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | caravelas
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | pisco
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | grand baie
# Processing Record 11 of Set 1 | norman wells
# Processing Record 12 of Set 1 | hami
# Processing Record 13 of Set 1 | longyearbyen
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | riyadh
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | amapa
# Processing Record 19 of Set 1 | izazi
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | saint-philippe
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | bambous virieux
# Processing Record 24 of Set 1 | coahuayana
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | cap-chat
# Processing Record 27 of Set 1 | victoria
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | lalmohan
# Processing Record 30 of Set 1 | labuhan
# Processing Record 31 of Set 1 | waipawa
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | flin flon
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | kainantu
# Processing Record 40 of Set 1 | saint george
# Processing Record 41 of Set 1 | pangnirtung
# Processing Record 42 of Set 1 | lavrentiya
# Processing Record 43 of Set 1 | ahipara
# Processing Record 44 of Set 1 | isangel
# Processing Record 45 of Set 1 | kalachinsk
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | port lincoln
# Processing Record 48 of Set 1 | sabha
# Processing Record 49 of Set 1 | san juan
# Processing Record 50 of Set 1 | sangar
# Processing Record 1 of Set 2 | vao
# Processing Record 2 of Set 2 | necochea
# Processing Record 3 of Set 2 | zhangye
# Processing Record 4 of Set 2 | aloleng
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 2 | sisimiut
# Processing Record 8 of Set 2 | grand gaube
# Processing Record 9 of Set 2 | sao filipe
# Processing Record 10 of Set 2 | port shepstone
# Processing Record 11 of Set 2 | dengzhou
# Processing Record 12 of Set 2 | harper
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | sisophon
# Processing Record 15 of Set 2 | the valley
# Processing Record 16 of Set 2 | ambon
# Processing Record 17 of Set 2 | nikolsk
# Processing Record 18 of Set 2 | inirida
# Processing Record 19 of Set 2 | labuan
# Processing Record 20 of Set 2 | cabedelo
# Processing Record 21 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | hachinohe
# Processing Record 24 of Set 2 | faanui
# Processing Record 25 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 26 of Set 2 | kulhudhuffushi
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | huazolotitlan
# City not found. Skipping...
# Processing Record 29 of Set 2 | kalga
# Processing Record 30 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 2 | cape town
# Processing Record 32 of Set 2 | airai
# Processing Record 33 of Set 2 | camocim
# Processing Record 34 of Set 2 | dingle
# Processing Record 35 of Set 2 | ozernovskiy
# Processing Record 36 of Set 2 | mugumu
# Processing Record 37 of Set 2 | aklavik
# Processing Record 38 of Set 2 | elko
# Processing Record 39 of Set 2 | kaitangata
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | cabo san lucas
# Processing Record 42 of Set 2 | svetlogorsk
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | mahebourg
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 2 | priladozhskiy
# Processing Record 48 of Set 2 | torbay
# Processing Record 49 of Set 2 | salalah
# Processing Record 50 of Set 2 | amzya
# Processing Record 1 of Set 3 | maniitsoq
# Processing Record 2 of Set 3 | teahupoo
# Processing Record 3 of Set 3 | waterford
# Processing Record 4 of Set 3 | kedrovyy
# Processing Record 5 of Set 3 | ilulissat
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | charters towers
# Processing Record 8 of Set 3 | georgetown
# Processing Record 9 of Set 3 | lagoa
# Processing Record 10 of Set 3 | itoman
# Processing Record 11 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 3 | rundu
# Processing Record 13 of Set 3 | kapit
# Processing Record 14 of Set 3 | grindavik
# Processing Record 15 of Set 3 | mayor pablo lagerenza
# Processing Record 16 of Set 3 | port elizabeth
# Processing Record 17 of Set 3 | lebu
# Processing Record 18 of Set 3 | gorin
# Processing Record 19 of Set 3 | tilichiki
# Processing Record 20 of Set 3 | zeerust
# Processing Record 21 of Set 3 | cayenne
# Processing Record 22 of Set 3 | mount gambier
# Processing Record 23 of Set 3 | tuatapere
# Processing Record 24 of Set 3 | warri
# Processing Record 25 of Set 3 | mopti
# Processing Record 26 of Set 3 | kodiak
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | banda aceh
# Processing Record 29 of Set 3 | carnarvon
# Processing Record 30 of Set 3 | olafsvik
# Processing Record 31 of Set 3 | lompoc
# Processing Record 32 of Set 3 | henderson
# Processing Record 33 of Set 3 | hasaki
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 3 | fortuna
# Processing Record 37 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 3 | nanortalik
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | dzilam gonzalez
# Processing Record 41 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 3 | borogontsy
# Processing Record 43 of Set 3 | mildura
# Processing Record 44 of Set 3 | warrnambool
# Processing Record 45 of Set 3 | codrington
# Processing Record 46 of Set 3 | myitkyina
# Processing Record 47 of Set 3 | atbasar
# Processing Record 48 of Set 3 | palmares do sul
# Processing Record 49 of Set 3 | kruisfontein
# Processing Record 50 of Set 3 | whitefish
# Processing Record 1 of Set 4 | moron
# Processing Record 2 of Set 4 | yarada
# Processing Record 3 of Set 4 | raton
# Processing Record 4 of Set 4 | vacaria
# Processing Record 5 of Set 4 | castro
# Processing Record 6 of Set 4 | khandagayty
# Processing Record 7 of Set 4 | pottsville
# Processing Record 8 of Set 4 | danville
# Processing Record 9 of Set 4 | pacific grove
# Processing Record 10 of Set 4 | brahmapuri
# City not found. Skipping...
# Processing Record 11 of Set 4 | marquette
# Processing Record 12 of Set 4 | oliveira dos brejinhos
# Processing Record 13 of Set 4 | roros
# Processing Record 14 of Set 4 | parry sound
# Processing Record 15 of Set 4 | dikson
# Processing Record 16 of Set 4 | yulara
# Processing Record 17 of Set 4 | cabra
# Processing Record 18 of Set 4 | namatanai
# Processing Record 19 of Set 4 | ancud
# Processing Record 20 of Set 4 | port hawkesbury
# Processing Record 21 of Set 4 | san andres
# Processing Record 22 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 4 | margate
# Processing Record 24 of Set 4 | hofn
# Processing Record 25 of Set 4 | nayoro
# Processing Record 26 of Set 4 | kununurra
# Processing Record 27 of Set 4 | nishihara
# Processing Record 28 of Set 4 | henties bay
# Processing Record 29 of Set 4 | yankton
# Processing Record 30 of Set 4 | moindou
# Processing Record 31 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 4 | northam
# Processing Record 33 of Set 4 | kahului
# Processing Record 34 of Set 4 | sept-iles
# Processing Record 35 of Set 4 | yarke pole
# Processing Record 36 of Set 4 | mar del plata
# Processing Record 37 of Set 4 | san patricio
# Processing Record 38 of Set 4 | nouakchott
# Processing Record 39 of Set 4 | east london
# Processing Record 40 of Set 4 | olinda
# Processing Record 41 of Set 4 | bluff
# Processing Record 42 of Set 4 | salinopolis
# Processing Record 43 of Set 4 | liverpool
# Processing Record 44 of Set 4 | portland
# Processing Record 45 of Set 4 | ust-omchug
# Processing Record 46 of Set 4 | bonthe
# Processing Record 47 of Set 4 | carballo
# Processing Record 48 of Set 4 | ribeira grande
# Processing Record 49 of Set 4 | orneta
# Processing Record 50 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 5 | mount isa
# Processing Record 2 of Set 5 | acajutla
# Processing Record 3 of Set 5 | fuling
# Processing Record 4 of Set 5 | charcas
# Processing Record 5 of Set 5 | college
# Processing Record 6 of Set 5 | saint simons
# Processing Record 7 of Set 5 | zyryanka
# Processing Record 8 of Set 5 | catuday
# Processing Record 9 of Set 5 | padang
# Processing Record 10 of Set 5 | pastavy
# Processing Record 11 of Set 5 | sechura
# Processing Record 12 of Set 5 | san miguel
# Processing Record 13 of Set 5 | tarnogskiy gorodok
# Processing Record 14 of Set 5 | sola
# Processing Record 15 of Set 5 | neuquen
# Processing Record 16 of Set 5 | prince rupert
# Processing Record 17 of Set 5 | pecan grove
# Processing Record 18 of Set 5 | tual
# Processing Record 19 of Set 5 | harnosand
# Processing Record 20 of Set 5 | oranzherei
# Processing Record 21 of Set 5 | beidao
# Processing Record 22 of Set 5 | springfield
# Processing Record 23 of Set 5 | tateyama
# Processing Record 24 of Set 5 | marzuq
# Processing Record 25 of Set 5 | saquarema
# Processing Record 26 of Set 5 | port barton
# Processing Record 27 of Set 5 | kenai
# Processing Record 28 of Set 5 | klaksvik
# Processing Record 29 of Set 5 | abu samrah
# Processing Record 30 of Set 5 | gat
# Processing Record 31 of Set 5 | berlevag
# Processing Record 32 of Set 5 | sovetskiy
# Processing Record 33 of Set 5 | fairbanks
# Processing Record 34 of Set 5 | foix
# Processing Record 35 of Set 5 | ashtian
# Processing Record 36 of Set 5 | buala
# Processing Record 37 of Set 5 | trincomalee
# Processing Record 38 of Set 5 | lima
# Processing Record 39 of Set 5 | vila franca do campo
# Processing Record 40 of Set 5 | kolondieba
# Processing Record 41 of Set 5 | kutum
# Processing Record 42 of Set 5 | nantucket
# Processing Record 43 of Set 5 | kashan
# Processing Record 44 of Set 5 | gizo
# Processing Record 45 of Set 5 | kavieng
# Processing Record 46 of Set 5 | faya
# Processing Record 47 of Set 5 | nemuro
# Processing Record 48 of Set 5 | guerrero negro
# Processing Record 49 of Set 5 | adra
# Processing Record 50 of Set 5 | cartagena
# Processing Record 1 of Set 6 | geraldton
# Processing Record 2 of Set 6 | les escoumins
# Processing Record 3 of Set 6 | huatulco
# Processing Record 4 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 6 | garowe
# Processing Record 6 of Set 6 | fare
# Processing Record 7 of Set 6 | chuy
# Processing Record 8 of Set 6 | cherskiy
# Processing Record 9 of Set 6 | shelburne
# Processing Record 10 of Set 6 | xichang
# Processing Record 11 of Set 6 | norsup
# Processing Record 12 of Set 6 | muros
# Processing Record 13 of Set 6 | los llanos de aridane
# Processing Record 14 of Set 6 | walvis bay
# Processing Record 15 of Set 6 | pousat
# City not found. Skipping...
# Processing Record 16 of Set 6 | vranovice
# Processing Record 17 of Set 6 | taoudenni
# Processing Record 18 of Set 6 | marawi
# Processing Record 19 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 6 | mount pleasant
# Processing Record 21 of Set 6 | am timan
# Processing Record 22 of Set 6 | kawalu
# Processing Record 23 of Set 6 | ponta do sol
# Processing Record 24 of Set 6 | iselin
# Processing Record 25 of Set 6 | la palma
# Processing Record 26 of Set 6 | coihaique
# Processing Record 27 of Set 6 | saint anthony
# Processing Record 28 of Set 6 | murgab
# Processing Record 29 of Set 6 | rio verde de mato grosso
# Processing Record 30 of Set 6 | shuangyang
# Processing Record 31 of Set 6 | sopelana
# Processing Record 32 of Set 6 | acapulco
# Processing Record 33 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 6 | canberra
# Processing Record 35 of Set 6 | lorengau
# Processing Record 36 of Set 6 | bay roberts
# Processing Record 37 of Set 6 | sol-iletsk
# Processing Record 38 of Set 6 | chippewa falls
# Processing Record 39 of Set 6 | aykhal
# Processing Record 40 of Set 6 | vuktyl
# Processing Record 41 of Set 6 | chokwe
# Processing Record 42 of Set 6 | leningradskiy
# Processing Record 43 of Set 6 | owando
# Processing Record 44 of Set 6 | shankargarh
# Processing Record 45 of Set 6 | kodinsk
# Processing Record 46 of Set 6 | dezhou
# Processing Record 47 of Set 6 | pochinki
# Processing Record 48 of Set 6 | houlton
# Processing Record 49 of Set 6 | ukhta
# Processing Record 50 of Set 6 | saint-pierre
# Processing Record 1 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 7 | daru
# Processing Record 3 of Set 7 | kochevo
# Processing Record 4 of Set 7 | kavaratti
# Processing Record 5 of Set 7 | kysyl-syr
# Processing Record 6 of Set 7 | sioux lookout
# Processing Record 7 of Set 7 | marica
# Processing Record 8 of Set 7 | tefe
# Processing Record 9 of Set 7 | marsh harbour
# Processing Record 10 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 7 | sakaiminato
# Processing Record 12 of Set 7 | dunayivtsi
# City not found. Skipping...
# Processing Record 13 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 7 | santa cruz
# Processing Record 15 of Set 7 | saldanha
# Processing Record 16 of Set 7 | kamenka
# Processing Record 17 of Set 7 | tuktoyaktuk
# Processing Record 18 of Set 7 | escalerillas
# Processing Record 19 of Set 7 | ufa
# Processing Record 20 of Set 7 | dwarka
# Processing Record 21 of Set 7 | muscatine
# Processing Record 22 of Set 7 | llanes
# Processing Record 23 of Set 7 | namibe
# Processing Record 24 of Set 7 | pafos
# Processing Record 25 of Set 7 | tocantinopolis
# City not found. Skipping...
# Processing Record 26 of Set 7 | mahibadhoo
# Processing Record 27 of Set 7 | erzin
# Processing Record 28 of Set 7 | safonovo
# Processing Record 29 of Set 7 | carora
# Processing Record 30 of Set 7 | chapleau
# Processing Record 31 of Set 7 | sibolga
# Processing Record 32 of Set 7 | alofi
# Processing Record 33 of Set 7 | kyren
# Processing Record 34 of Set 7 | ostrovnoy
# Processing Record 35 of Set 7 | axim
# Processing Record 36 of Set 7 | tasiilaq
# Processing Record 37 of Set 7 | albert lea
# Processing Record 38 of Set 7 | nouadhibou
# Processing Record 39 of Set 7 | thunder bay
# Processing Record 40 of Set 7 | trairi
# Processing Record 41 of Set 7 | chumikan
# Processing Record 42 of Set 7 | bella vista
# Processing Record 43 of Set 7 | mata
# Processing Record 44 of Set 7 | lasa
# Processing Record 45 of Set 7 | turayf
# Processing Record 46 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 47 of Set 7 | port macquarie
# Processing Record 48 of Set 7 | trat
# Processing Record 49 of Set 7 | vila velha
# Processing Record 50 of Set 7 | byron bay
# Processing Record 1 of Set 8 | bandarbeyla
# Processing Record 2 of Set 8 | pevek
# Processing Record 3 of Set 8 | bonavista
# Processing Record 4 of Set 8 | grand forks
# Processing Record 5 of Set 8 | tevaitoa
# Processing Record 6 of Set 8 | tiksi
# Processing Record 7 of Set 8 | patea
# Processing Record 8 of Set 8 | wanning
# Processing Record 9 of Set 8 | hamilton
# Processing Record 10 of Set 8 | sao joao da barra
# Processing Record 11 of Set 8 | clyde river
# Processing Record 12 of Set 8 | sitka
# Processing Record 13 of Set 8 | shimoda
# Processing Record 14 of Set 8 | aviles
# Processing Record 15 of Set 8 | pangkalanbuun
# Processing Record 16 of Set 8 | jiayuguan
# Processing Record 17 of Set 8 | makushino
# Processing Record 18 of Set 8 | tuy hoa
# Processing Record 19 of Set 8 | jhalu
# Processing Record 20 of Set 8 | kisangani
# Processing Record 21 of Set 8 | coxim
# Processing Record 22 of Set 8 | kiama
# Processing Record 23 of Set 8 | taltal
# Processing Record 24 of Set 8 | jardim
# Processing Record 25 of Set 8 | ponta delgada
# Processing Record 26 of Set 8 | hadejia
# Processing Record 27 of Set 8 | mena
# Processing Record 28 of Set 8 | sobolevo
# Processing Record 29 of Set 8 | kerman
# Processing Record 30 of Set 8 | rioja
# Processing Record 31 of Set 8 | arlit
# Processing Record 32 of Set 8 | baykit
# Processing Record 33 of Set 8 | chapais
# Processing Record 34 of Set 8 | swan hill
# Processing Record 35 of Set 8 | sant pere de ribes
# Processing Record 36 of Set 8 | santiago del estero
# Processing Record 37 of Set 8 | izumo
# Processing Record 38 of Set 8 | iqaluit
# Processing Record 39 of Set 8 | haines junction
# Processing Record 40 of Set 8 | constitucion
# Processing Record 41 of Set 8 | merauke
# Processing Record 42 of Set 8 | hokitika
# Processing Record 43 of Set 8 | goma
# Processing Record 44 of Set 8 | san cristobal
# Processing Record 45 of Set 8 | puro
# Processing Record 46 of Set 8 | uthal
# Processing Record 47 of Set 8 | gurupi
# Processing Record 48 of Set 8 | kijang
# Processing Record 49 of Set 8 | vostok
# Processing Record 50 of Set 8 | grootfontein
# Processing Record 1 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 9 | chokurdakh
# Processing Record 3 of Set 9 | kampot
# Processing Record 4 of Set 9 | roald
# Processing Record 5 of Set 9 | quelimane
# Processing Record 6 of Set 9 | hobyo
# Processing Record 7 of Set 9 | tongzi
# Processing Record 8 of Set 9 | husavik
# Processing Record 9 of Set 9 | sibanicu
# Processing Record 10 of Set 9 | adrar
# Processing Record 11 of Set 9 | ust-nera
# Processing Record 12 of Set 9 | norwood
# Processing Record 13 of Set 9 | carberry
# Processing Record 14 of Set 9 | sao raimundo das mangabeiras
# Processing Record 15 of Set 9 | nicoya
# Processing Record 16 of Set 9 | nova olinda do norte
# Processing Record 17 of Set 9 | nago
# Processing Record 18 of Set 9 | qaqortoq
# Processing Record 19 of Set 9 | lookan
# Processing Record 20 of Set 9 | beausejour
# Processing Record 21 of Set 9 | puerto leguizamo
# Processing Record 22 of Set 9 | hambantota
# Processing Record 23 of Set 9 | camangcamang
# Processing Record 24 of Set 9 | inverell
# Processing Record 25 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 9 | bengkulu
# Processing Record 27 of Set 9 | bahia honda
# Processing Record 28 of Set 9 | katsuura
# Processing Record 29 of Set 9 | sukumo
# Processing Record 30 of Set 9 | natal
# Processing Record 31 of Set 9 | rawson
# Processing Record 32 of Set 9 | talcahuano
# Processing Record 33 of Set 9 | agstafa
# City not found. Skipping...
# Processing Record 34 of Set 9 | smithers
# Processing Record 35 of Set 9 | kaniama
# Processing Record 36 of Set 9 | narrabri
# Processing Record 37 of Set 9 | noumea
# Processing Record 38 of Set 9 | porto novo
# Processing Record 39 of Set 9 | port hardy
# Processing Record 40 of Set 9 | luderitz
# Processing Record 41 of Set 9 | shahr-e babak
# Processing Record 42 of Set 9 | sao miguel
# Processing Record 43 of Set 9 | trzic
# Processing Record 44 of Set 9 | jucas
# Processing Record 45 of Set 9 | beian
# Processing Record 46 of Set 9 | srednekolymsk
# Processing Record 47 of Set 9 | yanam
# Processing Record 48 of Set 9 | north bend
# Processing Record 49 of Set 9 | praia da vitoria
# Processing Record 50 of Set 9 | severo-kurilsk
# Processing Record 1 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 10 | kalmunai
# Processing Record 3 of Set 10 | houston
# Processing Record 4 of Set 10 | acarau
# Processing Record 5 of Set 10 | kloulklubed
# Processing Record 6 of Set 10 | solnechnyy
# Processing Record 7 of Set 10 | tessalit
# Processing Record 8 of Set 10 | changli
# Processing Record 9 of Set 10 | dolores hidalgo
# Processing Record 10 of Set 10 | konevo
# Processing Record 11 of Set 10 | biak
# Processing Record 12 of Set 10 | mufumbwe
# Processing Record 13 of Set 10 | baruun-urt
# Processing Record 14 of Set 10 | udachnyy
# Processing Record 15 of Set 10 | antalaha
# Processing Record 16 of Set 10 | yashiro
# Processing Record 17 of Set 10 | baker city
# Processing Record 18 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 10 | lecce
# Processing Record 20 of Set 10 | honolulu
# Processing Record 21 of Set 10 | chara
# Processing Record 22 of Set 10 | mitu
# Processing Record 23 of Set 10 | kadnikov
# Processing Record 24 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 10 | ushtobe
# Processing Record 26 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 27 of Set 10 | khani
# Processing Record 28 of Set 10 | davila
# Processing Record 29 of Set 10 | tema
# Processing Record 30 of Set 10 | langxiang
# Processing Record 31 of Set 10 | carutapera
# Processing Record 32 of Set 10 | velikie luki
# City not found. Skipping...
# Processing Record 33 of Set 10 | weston
# Processing Record 34 of Set 10 | deputatskiy
# Processing Record 35 of Set 10 | west point
# Processing Record 36 of Set 10 | jalu
# Processing Record 37 of Set 10 | ahuimanu
# Processing Record 38 of Set 10 | road town
# Processing Record 39 of Set 10 | mahanoro
# Processing Record 40 of Set 10 | aguimes
# Processing Record 41 of Set 10 | cidreira
# Processing Record 42 of Set 10 | stephenville
# Processing Record 43 of Set 10 | warragul
# Processing Record 44 of Set 10 | xiongzhou
# Processing Record 45 of Set 10 | komsomolskiy
# Processing Record 46 of Set 10 | langarud
# Processing Record 47 of Set 10 | quedlinburg
# Processing Record 48 of Set 10 | lambontong
# Processing Record 49 of Set 10 | tomatlan
# Processing Record 50 of Set 10 | el tarra
# Processing Record 1 of Set 11 | kieta
# Processing Record 2 of Set 11 | general pico
# Processing Record 3 of Set 11 | novyy urengoy
# Processing Record 4 of Set 11 | aksu
# Processing Record 5 of Set 11 | holme
# Processing Record 6 of Set 11 | chore
# City not found. Skipping...
# Processing Record 7 of Set 11 | amot
# Processing Record 8 of Set 11 | westport
# Processing Record 9 of Set 11 | tulagi
# Processing Record 10 of Set 11 | logansport
# Processing Record 11 of Set 11 | kasongo-lunda
# Processing Record 12 of Set 11 | kalianget
# Processing Record 13 of Set 11 | santa marta
# Processing Record 14 of Set 11 | ola
# Processing Record 15 of Set 11 | fort saint james
# Processing Record 16 of Set 11 | ocos
# Processing Record 17 of Set 11 | yar-sale
# Processing Record 18 of Set 11 | rio grande
# Processing Record 19 of Set 11 | dolinsk
# Processing Record 20 of Set 11 | kiunga
# Processing Record 21 of Set 11 | guasdualito
# Processing Record 22 of Set 11 | pasni
# Processing Record 23 of Set 11 | lazaro cardenas
# Processing Record 24 of Set 11 | yanchukan
# City not found. Skipping...
# Processing Record 25 of Set 11 | whitehorse
# Processing Record 26 of Set 11 | turkistan
# Processing Record 27 of Set 11 | bosaso
# Processing Record 28 of Set 11 | bardiyah
# Processing Record 29 of Set 11 | cajamarca
# Processing Record 30 of Set 11 | mahon
# Processing Record 31 of Set 11 | saint-joseph
# Processing Record 32 of Set 11 | anadyr
# Processing Record 33 of Set 11 | mattawa
# Processing Record 34 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 11 | colac
# Processing Record 36 of Set 11 | tautira
# Processing Record 37 of Set 11 | barra
# Processing Record 38 of Set 11 | iskateley
# Processing Record 39 of Set 11 | alakurtti
# Processing Record 40 of Set 11 | miraflores
# Processing Record 41 of Set 11 | shahpura
# Processing Record 42 of Set 11 | skalnyy
# City not found. Skipping...
# Processing Record 43 of Set 11 | marfino
# Processing Record 44 of Set 11 | jaca
# Processing Record 45 of Set 11 | meulaboh
# Processing Record 46 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 11 | talnakh
# Processing Record 48 of Set 11 | ceres
# Processing Record 49 of Set 11 | yumen
# Processing Record 50 of Set 11 | esfarayen
# Processing Record 1 of Set 12 | najran
# Processing Record 2 of Set 12 | chateauroux
# Processing Record 3 of Set 12 | cockburn town
# Processing Record 4 of Set 12 | harindanga
# Processing Record 5 of Set 12 | staryy nadym
# Processing Record 6 of Set 12 | kopaganj
# Processing Record 7 of Set 12 | kalino
# Processing Record 8 of Set 12 | champawat
# Processing Record 9 of Set 12 | sao joao evangelista
# Processing Record 10 of Set 12 | orlik
# Processing Record 11 of Set 12 | souillac
# Processing Record 12 of Set 12 | severobaykalsk
# Processing Record 13 of Set 12 | esperance
# Processing Record 14 of Set 12 | esso
# Processing Record 15 of Set 12 | la ronge
# Processing Record 16 of Set 12 | redmond
# Processing Record 17 of Set 12 | sidi ali
# Processing Record 18 of Set 12 | te anau
# Processing Record 19 of Set 12 | taksimo
# Processing Record 20 of Set 12 | terme
# Processing Record 21 of Set 12 | vanimo
# Processing Record 22 of Set 12 | pandan
# Processing Record 23 of Set 12 | batouri
# Processing Record 24 of Set 12 | korla
# Processing Record 25 of Set 12 | menongue
# Processing Record 26 of Set 12 | talaya
# Processing Record 27 of Set 12 | tome-acu
# City not found. Skipping...
# Processing Record 28 of Set 12 | brodowski
# Processing Record 29 of Set 12 | juneau
# Processing Record 30 of Set 12 | lata
# Processing Record 31 of Set 12 | pringsewu
# Processing Record 32 of Set 12 | sorland
# Processing Record 33 of Set 12 | mafinga
# Processing Record 34 of Set 12 | starozhilovo
# Processing Record 35 of Set 12 | krutinka
# Processing Record 36 of Set 12 | abnub
# Processing Record 37 of Set 12 | huntington
# Processing Record 38 of Set 12 | vardo
# Processing Record 39 of Set 12 | touros
# Processing Record 40 of Set 12 | aksum
# Processing Record 41 of Set 12 | nome
# Processing Record 42 of Set 12 | baculin
# Processing Record 43 of Set 12 | owatonna
# Processing Record 44 of Set 12 | tukrah
# Processing Record 45 of Set 12 | vondrozo
# Processing Record 46 of Set 12 | lakes entrance
# Processing Record 47 of Set 12 | namie
# Processing Record 48 of Set 12 | ulaangom
# Processing Record 49 of Set 12 | yining
# Processing Record 50 of Set 12 | ostersund
# Processing Record 1 of Set 13 | rancho palos verdes
# Processing Record 2 of Set 13 | shizuishan
# Processing Record 3 of Set 13 | umm kaddadah
# Processing Record 4 of Set 13 | kovacica
# Processing Record 5 of Set 13 | coari
# Processing Record 6 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 13 | saint-augustin
# Processing Record 9 of Set 13 | dali
# Processing Record 10 of Set 13 | ankang
# Processing Record 11 of Set 13 | lomovka
# Processing Record 12 of Set 13 | agadez
# Processing Record 13 of Set 13 | tokonou
# Processing Record 14 of Set 13 | iberia
# Processing Record 15 of Set 13 | ngerengere
# Processing Record 16 of Set 13 | dongli
# Processing Record 17 of Set 13 | batagay-alyta
# Processing Record 18 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 13 | samana
# Processing Record 20 of Set 13 | uchiza
# Processing Record 21 of Set 13 | waddan
# Processing Record 22 of Set 13 | zhuhai
# Processing Record 23 of Set 13 | mobaye
# Processing Record 24 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 13 | amethi
# Processing Record 26 of Set 13 | villarrica
# Processing Record 27 of Set 13 | emba
# Processing Record 28 of Set 13 | hatillo
# Processing Record 29 of Set 13 | kyshtovka
# Processing Record 30 of Set 13 | bara
# Processing Record 31 of Set 13 | aswan
# Processing Record 32 of Set 13 | abiy adi
# City not found. Skipping...
# Processing Record 33 of Set 13 | zaysan
# Processing Record 34 of Set 13 | dunda
# Processing Record 35 of Set 13 | revda
# Processing Record 36 of Set 13 | terney
# Processing Record 37 of Set 13 | aras
# Processing Record 38 of Set 13 | yuzhno-sukhokumsk
# Processing Record 39 of Set 13 | oktyabrskoye
# Processing Record 40 of Set 13 | santiago de cao
# Processing Record 41 of Set 13 | wschowa
# Processing Record 42 of Set 13 | lockport
# Processing Record 43 of Set 13 | beaverlodge
# Processing Record 44 of Set 13 | altena
# Processing Record 45 of Set 13 | todos santos
# Processing Record 46 of Set 13 | san jose
# Processing Record 47 of Set 13 | bria
# Processing Record 48 of Set 13 | kohlu
# Processing Record 49 of Set 13 | quatre cocos
# Processing Record 50 of Set 13 | half moon bay
# Processing Record 1 of Set 14 | monrovia
# Processing Record 2 of Set 14 | tiznit
# Processing Record 3 of Set 14 | oyama
# Processing Record 4 of Set 14 | kushima
# Processing Record 5 of Set 14 | santa isabel do rio negro
# Processing Record 6 of Set 14 | preobrazheniye
# Processing Record 7 of Set 14 | chunoyar
# Processing Record 8 of Set 14 | zheleznodorozhnyy
# Processing Record 9 of Set 14 | beyla
# Processing Record 10 of Set 14 | witu
# Processing Record 11 of Set 14 | san quintin
# Processing Record 12 of Set 14 | lisakovsk
# Processing Record 13 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 14 of Set 14 | roebourne
# Processing Record 15 of Set 14 | mafeteng
# Processing Record 16 of Set 14 | ambilobe
# Processing Record 17 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 18 of Set 14 | birjand
# Processing Record 19 of Set 14 | ahmadpur east
# Processing Record 20 of Set 14 | hualmay
# Processing Record 21 of Set 14 | mayo
# Processing Record 22 of Set 14 | nueve de julio
# Processing Record 23 of Set 14 | port hedland
# Processing Record 24 of Set 14 | hinton
# Processing Record 25 of Set 14 | caruray
# Processing Record 26 of Set 14 | papetoai
# Processing Record 27 of Set 14 | angra
# City not found. Skipping...
# Processing Record 28 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 29 of Set 14 | tortoli
# Processing Record 30 of Set 14 | maceio
# Processing Record 31 of Set 14 | pauini
# Processing Record 32 of Set 14 | new philadelphia
# Processing Record 33 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 35 of Set 14 | gao
# Processing Record 36 of Set 14 | hovd
# Processing Record 37 of Set 14 | luba
# Processing Record 38 of Set 14 | dunedin
# Processing Record 39 of Set 14 | vestmanna
# Processing Record 40 of Set 14 | abha
# Processing Record 41 of Set 14 | mindelo
# Processing Record 42 of Set 14 | tura
# Processing Record 43 of Set 14 | breznik
# Processing Record 44 of Set 14 | bend
# Processing Record 45 of Set 14 | panzhihua
# Processing Record 46 of Set 14 | nuuk
# Processing Record 47 of Set 14 | mandaguacu
# Processing Record 48 of Set 14 | mogadouro
# Processing Record 49 of Set 14 | alice town
# Processing Record 50 of Set 14 | la rochelle
# Processing Record 1 of Set 15 | leiyang
# Processing Record 2 of Set 15 | manzil jamil
# City not found. Skipping...
# Processing Record 3 of Set 15 | malartic
# Processing Record 4 of Set 15 | sheridan
# Processing Record 5 of Set 15 | yunyang
# Processing Record 6 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 7 of Set 15 | vestmannaeyjar
# Processing Record 8 of Set 15 | kalabo
# Processing Record 9 of Set 15 | eyl
# Processing Record 10 of Set 15 | balkanabat
# Processing Record 11 of Set 15 | seydi
# Processing Record 12 of Set 15 | kasese
# Processing Record 13 of Set 15 | pathein
# Processing Record 14 of Set 15 | erenhot
# Processing Record 15 of Set 15 | panaba
# Processing Record 16 of Set 15 | presidencia roque saenz pena
# Processing Record 17 of Set 15 | wanaka
# Processing Record 18 of Set 15 | zhangjiakou
# Processing Record 19 of Set 15 | san vicente
# Processing Record 20 of Set 15 | luanda
# Processing Record 21 of Set 15 | muzhi
# Processing Record 22 of Set 15 | puerto ayacucho
# Processing Record 23 of Set 15 | mogadishu
# Processing Record 24 of Set 15 | puerto escondido
# Processing Record 25 of Set 15 | bubaque
# Processing Record 26 of Set 15 | bathsheba
# Processing Record 27 of Set 15 | cururupu
# Processing Record 28 of Set 15 | tucuma
# Processing Record 29 of Set 15 | antigonish
# Processing Record 30 of Set 15 | senador pompeu
# Processing Record 31 of Set 15 | verkhnyaya inta
# Processing Record 32 of Set 15 | bairiki
# Processing Record 33 of Set 15 | bima
# Processing Record 34 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 15 | busko-zdroj
# Processing Record 36 of Set 15 | montecristi
# Processing Record 37 of Set 15 | itarema
# Processing Record 38 of Set 15 | grezzana
# Processing Record 39 of Set 15 | dekar
# Processing Record 40 of Set 15 | urambo
# Processing Record 41 of Set 15 | kayerkan
# Processing Record 42 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 43 of Set 15 | kattivakkam
# Processing Record 44 of Set 15 | broome
# Processing Record 45 of Set 15 | sabang
# Processing Record 46 of Set 15 | sadasivpet
# Processing Record 47 of Set 15 | balimo
# City not found. Skipping...
# Processing Record 48 of Set 15 | port blair
# Processing Record 49 of Set 15 | meadow lake
# Processing Record 50 of Set 15 | ovsyanka
# Processing Record 1 of Set 16 | wajima
# Processing Record 2 of Set 16 | nisporeni
# Processing Record 3 of Set 16 | bure
# Processing Record 4 of Set 16 | ayagoz
# Processing Record 5 of Set 16 | burkhala
# City not found. Skipping...
# Processing Record 6 of Set 16 | flinders
# Processing Record 7 of Set 16 | brigantine
# Processing Record 8 of Set 16 | borsa
# Processing Record 9 of Set 16 | avera
# Processing Record 10 of Set 16 | shenzhen
# Processing Record 11 of Set 16 | eureka
# Processing Record 12 of Set 16 | humacao
# Processing Record 13 of Set 16 | tongchuan
# Processing Record 14 of Set 16 | aleksandro-nevskiy
# Processing Record 15 of Set 16 | yarmouth
# Processing Record 16 of Set 16 | sakakah
# Processing Record 17 of Set 16 | mokhsogollokh
# Processing Record 18 of Set 16 | isoka
# Processing Record 19 of Set 16 | attawapiskat
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0    Caravelas -17.7125  -39.2481    scattered clouds     75.43        94
# 1   Nikolskoye  59.7035   30.7861          light snow     24.69        97
# 2        Pisco -13.7000  -76.2167           clear sky     69.85        73
# 3   Bredasdorp -34.5322   20.0403       broken clouds     59.29        75
# 4        Kapaa  22.0752 -159.3190           clear sky     78.78        71
# 5      Mataura -46.1927  168.8643       broken clouds     66.47        24
# 6      Rikitea -23.1203 -134.9692     overcast clouds     77.86        74
# 7     Hermanus -34.4187   19.2345    scattered clouds     59.81        81
# 8  New Norfolk -42.7826  147.0587     overcast clouds     71.91        52
# 9   Grand Baie -20.0182   57.5802           clear sky     83.44        72
#
#    Cloudiness  Wind Speed
# 0          40        6.24
# 1          97        5.93
# 2           0        3.44
# 3          52        6.40
# 4           0        1.01
# 5          75        7.23
# 6          92       13.80
# 7          35       11.90
# 8          99        4.00
# 9           1        5.01

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
